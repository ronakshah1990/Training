# %% [markdown]
# <a href="https://colab.research.google.com/github/ronakshah1990/Training/blob/Data-Analysis-with-Pandas-and-Python---Boris-Paskhaver/Chapter_2_Python_Crash_Course.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Comments**

# %%
# Author: Ronak Shah
# Solve mathematical expressions using Python
3+3
# Out:
# 6

# %%
3 + 3
# 5 + 5
# 10 + 10
# Out:
# 6

# %%
# Author: Ronak Shah
3 + 3
5 + 5
10 + 10 # Solve mathematical expressions using Python

# %% [markdown]
# Adding a text cell instead of a comment in a code cell.

# %% [markdown]
# **Basic Data Types**

# %%
# Integers - whole number
5
10
-23
0
# Out:
# 0

# %%
# Floating-point - number with a decimal/fractional component
3.14
3.14159
9.99
-113.23819
# Out:
# -113.23819

# %%
# String - a [iece of text, collection of characters
"Ronak"
# Out:
# 'Ronak'

# %%
"123dollars.!@#$%^"
# Out:
# '123dollars.!@#$%^'

# %%
"Ronak" 'Sunil' 'Shah'
# Out:
# 'RonakSunilShah'

# %%
139.99 + 4.15
# Out:
# 144.14000000000001

# %%
"139.99" + 4.15
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-51ce3e4fff5f> in <cell line: 1>()
# ----> 1 "139.99" + 4.15
#
# TypeError: can only concatenate str (not "float") to str

# %%
4.15 + "139.99"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-d5b0e99f3d35> in <cell line: 1>()
# ----> 1 4.15 + "139.99"
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
# Empty string - a string without characters
""
# Out:
# ''

# %%
# Boolean - Named after George Bool
True
False
# Out:
# False

# %%
5 < 7
# Out:
# True

# %%
10 > 12
# Out:
# False

# %%
# None - a type that represents absence/nullness/a missing value
None

# %%
none
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-02135ff9133d> in <cell line: 1>()
# ----> 1 none
#
# NameError: name 'none' is not defined

# %% [markdown]
# **Operators**
#
#
#
# *   An operator is a symbol that performs an operation (mathematical, logical, etc.)
